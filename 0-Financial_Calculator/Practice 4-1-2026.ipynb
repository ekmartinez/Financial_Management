# %%
import numpy as np
import numpy_financial as npf
from calculator import Time_value

# %%
"""
Args:
            pv (float):  Present value.
            fv (float):  Future value.
            rt (float):  Rate.
            pmt (float): Payment.
            prd (int):   Periods.
            cmp (int):   Compounding.
            ann (str):   When? 'end', 'begin'
            compt (str): Computation (pv, fv, rate, nper, pmt)
"""

# %%
pv = -3
fv = 4
rt = 0
pmt = 0
npr = 1
cmp = 1
ann = "end"
compt = "rt"

pvalue = Time_value(pv, fv, rt, pmt, npr, cmp, ann, compt)
print(pvalue.compute())

# %%
fv = 4
pv = 1
n = 12
m = 3
r = npf.rate(fv=fv, pv=-pv, nper=n/m, pmt=0)
r
# Out:
# np.float64(0.414213562373214)
