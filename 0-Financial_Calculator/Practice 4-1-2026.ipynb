# %%
import numpy as np
import numpy_financial as npf
from calculator import Time_value

# %%
"""
Args:
            pv (float):  Present value.
            fv (float):  Future value.
            rt (float):  Rate.
            pmt (float): Payment.
            prd (int):   Periods.
            cmp (int):   Compounding.
            ann (str):   When? 'end', 'begin'
            compt (str): Computation (pv, fv, rate, nper, pmt)
"""

# %%
pv = -3
fv = 4
rt = 0
pmt = 0
npr = 1
cmp = 1
ann = "end"
compt = "rt"

pvalue = Time_value(pv, fv, rt, pmt, npr, cmp, ann, compt)
print(pvalue.compute())
# Out:
# Something went wrong

# %%
m = 52
r = npf.rate(pv=pv, fv=fv, pmt=0, nper=npr)
print(r)
apr = r * 52
print(apr)
ear = (1 + (apr/m))**m - 1
print(ear)
# Out:
# 0.33333333333333326
# 17.33333333333333
# 3139165.15690491

# %%
# Out:
# np.float64(nan)

# %%
n= 10
first_simple = .06

first_simple_interest = first_simple * n
# Out:
# 0.6
