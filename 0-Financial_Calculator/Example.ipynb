# %%
from calculator import Time_value

# %% [markdown]
# **Find Present Value**
#
# Given: FV = 5,000; rate = 6% annually; n = 4 periods; pmt = 0
#
# Find: PV

# %%
pv = 0
fv = 5000
rt = .06
pmt = 0
npr = 4
cmp = 1
ann = "end"
compt = "pv"

pvalue = Time_value(pv, fv, rt, pmt, npr, cmp, ann, compt)
print(pvalue.compute()
# Out:
# -3960.468316190102

# %% [markdown]
# **Find Future Value**
#
# Given: PV = -2,000; rate = 5% annually; n = 6 periods; pmt = 0
# Find: FV

# %%
pv = -2000
fv = 0
rt = .05
pmt = 0
npr = 6
cmp = 1
ann = "end"
compt = "fv"

pvalue = Time_value(pv, fv, rt, pmt, npr, cmp, ann, compt)
print(pvalue.compute())
# Out:
# 2680.191281250001

# %% [markdown]
# **Find Rate**
#
# Given: PV = -1,500; FV = 0; pmt = 200 (payment at period end); n = 8 periods
#
# Find: rate per period

# %%
pv = -1500
fv = 0
rt = .0
pmt = 200
npr = 8
cmp = 1
ann = "end"
compt = "rate"

pvalue = Time_value(pv, fv, rt, pmt, npr, cmp, ann, compt)
print(pvalue.compute())
# Out:
# 0.014569024511893361

# %% [markdown]
# **Find Periods**
#
# Given: PV = -625; FV = 1,284; rate = 6% per period; pmt = 0
#
# Find: nper

# %%
pv = -625
fv = 1284
rt = .06
pmt = 0
npr = 0
cmp = 1
ann = "end"
compt = "nper"

periods = Time_value(pv, fv, rt, pmt, npr, cmp, ann, compt)
print(periods.compute())
# Out:
# 12.356226634307811

# %% [markdown]
# **Find Present Value of an Ordinary Annuity**
#
# Given: pmt = 1,200 (received at end of each period); rate = 7% per period; n = 10; fv = 0
#
# Find: PV (ordinary annuity)

# %%
pv = 0
fv = 0
rt = .07
pmt = 1200
npr = 10
cmp = 1
ann = "end"
compt = "pv"

ordinary = Time_value(pv, fv, rt, pmt, npr, cmp, ann, compt)
print(ordinary.compute())
# Out:
# -8428.297849119128
