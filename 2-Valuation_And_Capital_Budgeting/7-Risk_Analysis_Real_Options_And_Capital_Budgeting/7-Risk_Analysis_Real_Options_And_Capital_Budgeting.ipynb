# %% [markdown]
# # Chapter 7 - Real Analysis, Real Options and Capital Budgeting

# %% [markdown]
# **Selected Exercises**
#
# Corporate Finance 9th International Edition
#
# Ross, Westerfield, Jaffe
